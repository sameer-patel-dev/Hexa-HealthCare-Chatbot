# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize 
from pattern.en import suggest
import re
from nltk.corpus import stopwords

# %%
#Step 1 : Tokenize
def tokenize(text):
    words = word_tokenize(text)
    return words

#Step 2 : Correct words where alphabets are repeated unncessarily
#amazzzzing => amazzing
def reduce_lengthening(text):
    pattern = re.compile(r"(.)\1{2,}")
    return pattern.sub(r"\1\1", text)

#Step 3: Remove punctuation
def remove_punctuation(text):
    #without_punct = text.translate(str.maketrans("",""), str.punctuation)
    without_punct = re.sub(r'\W',' ',text)#remove non word characters
    return without_punct

#Step 4: Remove URLs and user mentions
def remove_user_mentions_urls(text):
    text = re.sub(r"(?:\@|https?\://)\S+", "", text)
    return text

#Step 5: Remove numbers
def remove_numbers(text):
    text = re.sub(r'\d',' ',text)
    return text

#Step 6: Remove stop words
def remove_stop_words(text):
    words = tokenize(text)
    new =[]
    for word in words:
        if word not in stopwords.words('english'):
            new.append(word)
    text = ' '.join(new)
    return text

#Text cleaning pipeline
def clean_text(text):
    text = reduce_lengthening(text)
    text = remove_user_mentions_urls(text)
    text = remove_punctuation(text)
    text = remove_stop_words(text)
    return text

# %%
df1 = pd.read_csv("df_diseases.csv")
df1.shape
# Out:
# (1182, 10)

# %%
df1_clean = df1.dropna(subset=['symptoms'])
df1_clean.shape
# Out:
# (1098, 10)

# %% [markdown]
# <h3>Clean symptoms</h3>

# %%
df1_clean['clean_symptoms'] = df1_clean.apply(lambda x: clean_text(x["symptoms"]),axis=1)
# Out:
# C:\Users\PRIYA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1_clean.head()
# Out:
#    Unnamed: 0                     name  \
# 0           0     Acanthosis nigricans
# 2           2  Achilles tendon rupture
# 3           3  Acute coronary syndrome
# 4           4              Adenomyosis
# 5           5     Adjustment disorders
#
#                                                 link  \
# 0  https://www.mayoclinic.org/diseases-conditions...
# 2  https://www.mayoclinic.org/diseases-conditions...
# 3  https://www.mayoclinic.org/diseases-conditions...
# 4  https://www.mayoclinic.org/diseases-conditions...
# 5  https://www.mayoclinic.org/diseases-conditions...
#
#                                             symptoms  \
# 0  ["Skin changes are the only signs of acanthosi...
# 2  ["Although it's possible to have no signs or s...
# 3  ['The signs and symptoms of acute coronary syn...
# 4  ['Sometimes, adenomyosis causes no signs or sy...
# 5  ['Signs and symptoms depend on the type of adj...
#
#                                               causes  \
# 0  ['Acanthosis nigricans has been associated wit...
# 2  ['Your Achilles tendon helps you point your fo...
# 3  ['Acute coronary syndrome usually results from...
# 4  ["The cause of adenomyosis isn't known. There ...
# 5  ['Adjustment disorders are caused by significa...
#
#                                          risk_factor  \
# 0  ['Acanthosis nigricans risk factors include:',...
# 2  ['Factors that may increase your risk of Achil...
# 3  ['The risk factors for acute coronary syndrome...
# 4  ['Risk factors for adenomyosis include:', 'Mos...
# 5  ['Some things may make you more likely to have...
#
#                                             overview  \
# 0  ['Acanthosis nigricans is a skin condition tha...
# 2  ['The Achilles tendon is a strong fibrous cord...
# 3  ['Acute coronary syndrome is a term used to de...
# 4  ['With adenomyosis, the same tissue that lines...
# 5  ['Adjustment disorders are stress-related cond...
#
#                                            treatment  \
# 0  ['In many situations, treating the underlying ...
# 2  ['Treatment for a ruptured Achilles tendon oft...
# 3  ['The immediate goals of treatment for acute c...
# 4  ['Adenomyosis often goes away after menopause,...
# 5  ['Many people with adjustment disorders find t...
#
#                                           medication  \
# 0                                                NaN
# 2                                                NaN
# 3  ['Depending on your diagnosis, medications for...
# 4                                                NaN
# 5  ['Medications such as antidepressants and anti...
#
#                                        home_remedies  \
# 0                                                NaN
# 2                                                NaN
# 3  ['Heart healthy lifestyle changes are an impor...
# 4  ['To ease pelvic pain and cramping related to ...
# 5  ['Here are some steps you can take to care for...
#
#                                       clean_symptoms
# 0  Skin changes signs acanthosis nigricans You no...
# 2  Although possible signs symptoms Achilles tend...
# 3  The signs symptoms acute coronary syndrome usu...
# 4  Sometimes adenomyosis causes signs symptoms mi...
# 5  Signs symptoms depend type adjustment disorder...

# %%
df1_clean.to_csv("diseases_dataset.csv")

# %% [markdown]
# <h3>Re-evaluate for each query</h3>

# %%
df1_clean = pd.read_csv("diseases_dataset.csv")
#clean query
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

query = "ringing in ears, decreased hearing and giddiness"

clean_query = clean_text(query)

def get_similarity(clean_query,x):
    train_set = [clean_query,x['clean_symptoms']]
    tfidf_matrix_train   = TfidfVectorizer().fit_transform(train_set)
    score = cosine_similarity(tfidf_matrix_train[0:1], tfidf_matrix_train)[0][1]
    return score

# %%
df1_clean['score'] = df1_clean.apply(lambda x:get_similarity(clean_query,x),axis=1 )

# %%
ans = df1_clean.nlargest(10, ['score'])

# %%
ans
# Out:
#       Unnamed: 0  Unnamed: 0.1                                           name  \
# 196          222           222                                Earwax blockage
# 58            68            68                 Barotrauma (See: Airplane ear)
# 955         1031          1031                                       Tinnitus
# 663          726           726                Presbycusis (See: Hearing loss)
# 466          512           512                              Meniere's disease
# 846          918           918                               Spinal headaches
# 1053        1135          1135  Vestibular schwannoma (See: Acoustic neuroma)
# 517          567           567                       Nasopharyngeal carcinoma
# 748          816           816          Ruptured eardrum (perforated eardrum)
# 467          513           513                                     Meningioma
#
#                                                    link  \
# 196   https://www.mayoclinic.org/diseases-conditions...
# 58    https://www.mayoclinic.org/diseases-conditions...
# 955   https://www.mayoclinic.org/diseases-conditions...
# 663   https://www.mayoclinic.org/diseases-conditions...
# 466   https://www.mayoclinic.org/diseases-conditions...
# 846   https://www.mayoclinic.org/diseases-conditions...
# 1053  https://www.mayoclinic.org/diseases-conditions...
# 517   https://www.mayoclinic.org/diseases-conditions...
# 748   https://www.mayoclinic.org/diseases-conditions...
# 467   https://www.mayoclinic.org/diseases-conditions...
#
#                                                symptoms  \
# 196   ['Signs and symptoms of earwax blockage may in...
# 58    ['Airplane ear can occur in one or both ears. ...
# 955   ['Tinnitus involves the sensation of hearing s...
# 663   ['Signs and symptoms of hearing loss may inclu...
# 466   ["Signs and symptoms of Meniere's disease incl...
# 846   ['Spinal headache symptoms include:', 'Spinal ...
# 1053  ["Signs and symptoms of acoustic neuroma are o...
# 517   ['In its early stages, nasopharyngeal carcinom...
# 748   ['Signs and symptoms of a ruptured eardrum may...
# 467   ['Signs and symptoms of a meningioma typically...
#
#                                                  causes  \
# 196   ['The wax in your ears is secreted by glands i...
# 58    ['Airplane ear happens when there is an imbala...
# 955   ['A number of health conditions can cause or w...
# 663   ['To understand how hearing loss occurs, it ca...
# 466   ['Semicircular canals and otolith organs — the...
# 846   ['Spinal headaches are caused by leakage of sp...
# 1053  ['The cause of acoustic neuromas appears to be...
# 517   ['Cancer begins when one or more genetic mutat...
# 748   ['The middle ear includes three small bones — ...
# 467   ["It isn't clear what causes a meningioma. Doc...
#
#                                             risk_factor  \
# 196                                                 NaN
# 58    ['Any condition that blocks the eustachian tub...
# 955   ['Anyone can experience tinnitus, but these fa...
# 663   ['Factors that may damage or lead to loss of t...
# 466                                                 NaN
# 846   ['Risk factors for spinal headaches include:',...
# 1053  ['In an autosomal dominant disorder, the mutat...
# 517   ['Researchers have identified some factors tha...
# 748                                                 NaN
# 467   ['Risk factors for a meningioma include:', 'Ra...
#
#                                                overview  \
# 196   ['Earwax blockage occurs when earwax (cerumen)...
# 58    ["Airplane ear (ear barotrauma) is the stress ...
# 955   ['Tinnitus can be caused by broken or damaged ...
# 663   ['Hearing loss that occurs gradually as you ag...
# 466   ["Meniere's disease is a disorder of the inner...
# 846   ['Spinal headaches occur in up to 40 percent o...
# 1053  ['An acoustic neuroma (vestibular schwannoma) ...
# 517   ['The throat (pharynx) is a muscular tube that...
# 748   ['A ruptured (perforated) eardrum prevents the...
# 467   ['Three layers of membranes known as meninges ...
#
#                                               treatment  \
# 196   ['\n        Earwax removal by a doctorEarwax r...
# 58    ['For most people, airplane ear usually heals ...
# 955                                                  []
# 663   ['\n        Hearing aid partsHearing aid parts...
# 466   ["No cure exists for Meniere's disease. A numb...
# 846   ['Treatment for spinal headaches begins conser...
# 1053  ['Surgical removal of the tumor by an experien...
# 517   ["You and your doctor work together to devise ...
# 748   ['\n        TympanoplastyTympanoplastyIn some ...
# 467   ['The treatment you receive for a meningioma d...
#
#                                              medication  \
# 196                                                 NaN
# 58    ['Your doctor might suggest you take:', 'To ea...
# 955   ["Drugs can't cure tinnitus, but in some cases...
# 663                                                 NaN
# 466   ['Your doctor may prescribe medications to tak...
# 846                                                 NaN
# 1053                                                NaN
# 517                                                 NaN
# 748                                                 NaN
# 467                                                 NaN
#
#                                           home_remedies  \
# 196   ["If your eardrum doesn't contain a tube or ha...
# 58                                                  NaN
# 955   ["Often, tinnitus can't be treated. Some peopl...
# 663                                                 NaN
# 466   ["Certain self-care tactics can help reduce th...
# 846                                                 NaN
# 1053                                                NaN
# 517   ['Radiation therapy for nasopharyngeal carcino...
# 748   ['A ruptured (perforated) eardrum usually heal...
# 467                                                 NaN
#
#                                          clean_symptoms     score
# 196   Signs symptoms earwax blockage may include If ...  0.137905
# 58    Airplane ear occur one ears Common signs sympt...  0.137785
# 955   Tinnitus involves sensation hearing sound exte...  0.134487
# 663   Signs symptoms hearing loss may include If sud...  0.132771
# 466   Signs symptoms Meniere disease include After e...  0.094296
# 846   Spinal headache symptoms include Spinal headac...  0.091957
# 1053  Signs symptoms acoustic neuroma often subtle m...  0.091586
# 517   In early stages nasopharyngeal carcinoma may c...  0.085572
# 748   Signs symptoms ruptured eardrum may include Ca...  0.084173
# 467   Signs symptoms meningioma typically begin grad...  0.059124
